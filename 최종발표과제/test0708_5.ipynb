# %% [markdown]
# # 환경 설정

# %%
# 라이브러리 설정
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터셋 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#CSV파일을 읽어오기
drive_path = "/content/drive/MyDrive/"

train = pd.read_csv(drive_path + "dataset1.csv")

print(train.shape)
# Out:
# (1048575, 19)

# %% [markdown]
# # 데이터 살펴보기

# %% [markdown]
# ### 데이터 구조

# %%
# train 데이터프레임 내용 확인
train.head(3)
# Out:
#    STND_Y  IDV_ID   KEY_SEQ  SEX  AGE_GROUP  SIDO RECU_FR_DT  FORM_CD  \
# 0    2020      29   3724043    1         17    41 2020-12-21        3
# 1    2020      29   3495225    1         17    41 2020-12-14        3
# 2    2020     255  10615350    2         18    41 2020-04-20        3
#
#    DSBJT_CD MAIN_SICK  ... VSCN  RECN  EDEC_ADD_RT  EDEC_TRAMT  \
# 0         1      I109  ...    1     1         0.15       11540
# 1         1      I109  ...    1     1         0.15       11540
# 2         1      I109  ...    1     1         0.15       11540
#
#    EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  DATA_STD_DT month  season
# 0            1500           10040                0   2021-12-28    12       4
# 1            1500           10040                7   2021-12-28    12       4
# 2            1500           10040               30   2021-12-28     4       1
#
# [3 rows x 21 columns]

# %%
# train 데이터프레임 개요 정보
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   STND_Y           1048575 non-null  int64
#  1   IDV_ID           1048575 non-null  int64
#  2   KEY_SEQ          1048575 non-null  int64
#  3   SEX              1048575 non-null  int64
#  4   AGE_GROUP        1048575 non-null  int64
#  5   SIDO             1048575 non-null  int64
#  6   RECU_FR_DT       1048575 non-null  datetime64[ns]
#  7   FORM_CD          1048575 non-null  int64
#  8   DSBJT_CD         1048575 non-null  int64
#  9   MAIN_SICK        1048575 non-null  object
#  10  SUB_SICK         1048575 non-null  object
#  11  VSCN             1048575 non-null  int64
#  12  RECN             1048575 non-null  int64
#  13  EDEC_ADD_RT      1048575 non-null  float64
#  14  EDEC_TRAMT       1048575 non-null  int64
#  15  EDEC_SBRDN_AMT   1048575 non-null  int64
#  16  EDEC_JBRDN_AMT   1048575 non-null  int64
#  17  TOT_PRES_DD_CNT  1048575 non-null  int64
#  18  DATA_STD_DT      1048575 non-null  object
#  19  month            1048575 non-null  int64
#  20  season           1048575 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(16), object(3)
# memory usage: 168.0+ MB

# %%
# train 데이터프레임 통계정보
train.describe(include='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#            STND_Y        IDV_ID       KEY_SEQ           SEX     AGE_GROUP  \
# count   1048575.0  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# unique        NaN           NaN           NaN           NaN           NaN
# top           NaN           NaN           NaN           NaN           NaN
# freq          NaN           NaN           NaN           NaN           NaN
# first         NaN           NaN           NaN           NaN           NaN
# last          NaN           NaN           NaN           NaN           NaN
# mean       2020.0  1.661755e+05  5.659551e+06  1.562559e+00  1.123280e+01
# std           0.0  9.611398e+04  3.406616e+06  4.960712e-01  4.770835e+00
# min        2020.0  2.000000e+00  1.000000e+01  1.000000e+00  1.000000e+00
# 25%        2020.0  8.318050e+04  2.617641e+06  1.000000e+00  8.000000e+00
# 50%        2020.0  1.662400e+05  5.558405e+06  2.000000e+00  1.200000e+01
# 75%        2020.0  2.491910e+05  8.592534e+06  2.000000e+00  1.500000e+01
# max        2020.0  3.333330e+05  1.172724e+07  2.000000e+00  1.800000e+01
#
#                 SIDO           RECU_FR_DT       FORM_CD      DSBJT_CD  \
# count   1.048575e+06              1048575  1.048575e+06  1.048575e+06
# unique           NaN                  366           NaN           NaN
# top              NaN  2020-01-28 00:00:00           NaN           NaN
# freq             NaN                 7005           NaN           NaN
# first            NaN  2020-01-01 00:00:00           NaN           NaN
# last             NaN  2020-12-31 00:00:00           NaN           NaN
# mean    3.369546e+01                  NaN  2.999735e+00  6.451292e+00
# std     1.278442e+01                  NaN  1.628041e-02  6.457953e+00
# min     1.100000e+01                  NaN  2.000000e+00  0.000000e+00
# 25%     2.700000e+01                  NaN  3.000000e+00  1.000000e+00
# 50%     4.100000e+01                  NaN  3.000000e+00  4.000000e+00
# 75%     4.400000e+01                  NaN  3.000000e+00  1.300000e+01
# max     4.900000e+01                  NaN  3.000000e+00  5.500000e+01
#
#        MAIN_SICK  ...       VSCN       RECN   EDEC_ADD_RT    EDEC_TRAMT  \
# count    1048575  ...  1048575.0  1048575.0  1.048575e+06  1.048575e+06
# unique      4169  ...        NaN        NaN           NaN           NaN
# top         I109  ...        NaN        NaN           NaN           NaN
# freq      141027  ...        NaN        NaN           NaN           NaN
# first        NaN  ...        NaN        NaN           NaN           NaN
# last         NaN  ...        NaN        NaN           NaN           NaN
# mean         NaN  ...        1.0        1.0  1.500000e-01  1.549178e+04
# std          NaN  ...        0.0        0.0  2.775559e-17  1.828412e+04
# min          NaN  ...        1.0        1.0  1.500000e-01  1.530000e+03
# 25%          NaN  ...        1.0        1.0  1.500000e-01  1.154000e+04
# 50%          NaN  ...        1.0        1.0  1.500000e-01  1.362000e+04
# 75%          NaN  ...        1.0        1.0  1.500000e-01  1.614000e+04
# max          NaN  ...        1.0        1.0  1.500000e-01  3.278950e+06
#
#         EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  DATA_STD_DT  \
# count     1.048575e+06    1.048575e+06     1.048575e+06      1048575
# unique             NaN             NaN              NaN            1
# top                NaN             NaN              NaN   2021-12-28
# freq               NaN             NaN              NaN      1048575
# first              NaN             NaN              NaN          NaN
# last               NaN             NaN              NaN          NaN
# mean      3.198712e+03    1.229186e+04     1.467077e+01          NaN
# std       2.523003e+03    1.667087e+04     1.926278e+01          NaN
# min       0.000000e+00    3.000000e+01     0.000000e+00          NaN
# 25%       1.500000e+03    9.620000e+03     3.000000e+00          NaN
# 50%       3.400000e+03    1.083000e+04     5.000000e+00          NaN
# 75%       4.200000e+03    1.212000e+04     3.000000e+01          NaN
# max       3.517000e+05    2.951150e+06     3.650000e+02          NaN
#
#                month        season
# count   1.048575e+06  1.048575e+06
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean    6.340186e+00  2.589259e+00
# std     3.564714e+00  1.125482e+00
# min     1.000000e+00  1.000000e+00
# 25%     3.000000e+00  2.000000e+00
# 50%     6.000000e+00  3.000000e+00
# 75%     9.000000e+00  4.000000e+00
# max     1.200000e+01  4.000000e+00
#
# [13 rows x 21 columns]

# %% [markdown]
# ### 결측값 확인

# %%
# 결측값 분포
import missingno as msno
msno.bar(train, figsize=(10, 5), color=(0.7, 0.2, 0.2))
plt.show()

# %%
# 중복 데이터 확인
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# # 피처 엔지니어링
# - 문자열, 범주형 변수를 포함
# - 데이터 탐색(EDA) 및 전처리(pre-processing) 포함

# %%
train['RECU_FR_DT'] = pd.to_datetime(train['RECU_FR_DT'])
train['month']=train['RECU_FR_DT'].dt.month
train['season'] = 'winter'
train.loc[train['month']<12, 'season']='fall'
train.loc[train['month']<9, 'season']='summer'
train.loc[train['month']<6, 'season']='spring'
train.loc[(train['month']==1)| (train['month']==2), 'season']='winter'

# %%
df=train.loc[:,['SEX','AGE_GROUP','SIDO','MAIN_SICK','DSBJT_CD','EDEC_TRAMT','EDEC_SBRDN_AMT','EDEC_JBRDN_AMT','TOT_PRES_DD_CNT','season']]

# %%
#df=df[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400|J060|B351|J00|J303|N_|K297|F_|M170|M5456|M4806|J0190|K291|J040|J40|E785|J069|A099|L238|N185|A090|L500|L249|B353|J042|M511|J_|M179|L209|J329|J0100|K529|E782|J459|E039|J219|M171|S3350|L309|J320|N300')]
#df=df[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400|J060|B351|J00|J303|N_|K297|F_|M170|M5456|M4806|J0190|K291|J040|J40|E785|J069|A099|L238|N185|A090')]
#df=df[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400')]
df=df[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|J029|J0390|N400|J303|M170|M4806|J060|J00|M5456|J0190|J069|A099|A090')]
df.loc[(df['MAIN_SICK']=='J029')|(df['MAIN_SICK']=='J0390')|(df['MAIN_SICK']=='J060')|(df['MAIN_SICK']=='J00')|(df['MAIN_SICK']=='J0190')|(df['MAIN_SICK']=='J069'),'MAIN_SICK']='cold'
df.loc[(df['MAIN_SICK']=='A099')| (df['MAIN_SICK']=='A090'), 'MAIN_SICK']='Gastroenteritis '
df.loc[(df['MAIN_SICK']=='J304')| (df['MAIN_SICK']=='J303'), 'MAIN_SICK']='rhinitis '

# %%
df['MAIN_SICK']=df['MAIN_SICK'].astype('category').cat.codes
df['season']=df['season'].astype('category').cat.codes

# %%
#정규화 스케일링
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(df)

scaled = scaler.transform(df)
df_scaled = pd.DataFrame(data = scaled, columns=['SEX','AGE_GROUP','SIDO','MAIN_SICK','DSBJT_CD','EDEC_TRAMT','EDEC_SBRDN_AMT','EDEC_JBRDN_AMT','TOT_PRES_DD_CNT','season'])

# %%
df_scaled
# Out:
#              SEX  AGE_GROUP      SIDO  MAIN_SICK  DSBJT_CD  EDEC_TRAMT  \
# 0      -1.087947   1.156213  0.564871  -0.704720 -0.664358   -0.506256
# 1      -1.087947   1.156213  0.564871  -0.704720 -0.664358   -0.506256
# 2       0.919162   1.348160  0.564871  -0.704720 -0.664358   -0.506256
# 3       0.919162   1.348160  0.564871  -0.704720 -0.664358   -0.506256
# 4       0.919162   1.156213  0.564871  -0.704720 -0.664358   -0.506256
# ...          ...        ...       ...        ...       ...         ...
# 412190  0.919162   0.772318  0.564871   1.404696  1.219218    0.431881
# 412191 -1.087947   0.772318  0.802326   1.404696  1.219218    0.431881
# 412192 -1.087947   0.772318  0.802326   1.404696  1.219218    0.431881
# 412193 -1.087947   0.964265  0.564871   1.053126  1.533147    0.431881
# 412194 -1.087947   1.156213  0.564871  -0.353151 -0.664358    0.431881
#
#         EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT    season
# 0            -0.844408       -0.239029        -0.897342  1.202179
# 1            -0.844408       -0.239029        -0.573625  1.202179
# 2            -0.844408       -0.239029         0.490014 -0.509146
# 3            -0.844408       -0.239029         0.490014 -0.509146
# 4            -0.844408       -0.239029        -0.897342  1.202179
# ...                ...             ...              ...       ...
# 412190       -0.787562        0.840697        -0.712361  1.202179
# 412191       -0.787562        0.840697        -0.897342  0.346516
# 412192       -0.787562        0.840697        -0.897342  0.346516
# 412193       -0.787562        0.840697        -0.897342 -0.509146
# 412194       -0.787562        0.840697        -0.712361 -1.364809
#
# [412195 rows x 10 columns]

# %%
df
# Out:
#          SEX  AGE_GROUP  SIDO  MAIN_SICK  DSBJT_CD  EDEC_TRAMT  \
# 0          1         17    41          2         1       11540
# 1          1         17    41          2         1       11540
# 2          2         18    41          2         1       11540
# 3          2         18    41          2         1       11540
# 4          2         17    41          2         1       11540
# ...      ...        ...   ...        ...       ...         ...
# 1048569    2         15    41          8        13       16140
# 1048570    1         15    44          8        13       16140
# 1048571    1         15    44          8        13       16140
# 1048573    1         16    41          7        15       16140
# 1048574    1         17    41          3         1       16140
#
#          EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  season
# 0                  1500           10040                0       3
# 1                  1500           10040                7       3
# 2                  1500           10040               30       1
# 3                  1500           10040               30       1
# 4                  1500           10040                0       3
# ...                 ...             ...              ...     ...
# 1048569            1600           14540                4       3
# 1048570            1600           14540                0       2
# 1048571            1600           14540                0       2
# 1048573            1600           14540                0       1
# 1048574            1600           14540                4       0
#
# [412195 rows x 10 columns]

# %% [markdown]
# ### 모델링

# %%
#진료수 상위 30개만 가지고 모델링
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


X_data = df.loc[:,['SEX','AGE_GROUP','DSBJT_CD']]
y_data = df.loc[:,'MAIN_SICK']

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, shuffle = True, random_state=20)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (303651, 3) (303651,)
# (75913, 3) (75913,)

# %%
#진료수 상위 10개만 가지고 모델링 (scaled)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
#selected_features = ['SEX','AGE_GROUP','SIDO','DSBJT_CD','season']
selected_features = ['SEX','AGE_GROUP','SIDO','DSBJT_CD','EDEC_TRAMT','EDEC_SBRDN_AMT','EDEC_JBRDN_AMT','TOT_PRES_DD_CNT','season']
X_data = df_scaled.loc[:,selected_features]
y_data = df.loc[:,'MAIN_SICK']

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, shuffle = True, random_state=20)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (329756, 9) (329756,)
# (82439, 9) (82439,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=12)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
y_knn_tr_pred = knn.predict(X_train)
knn_tr_acc = accuracy_score(y_train, y_knn_tr_pred)
print("Accuracy : %4f" %knn_tr_acc)
# Out:
# Accuracy : 0.723023

# %%
y_knn_pred = knn.predict(X_test)
knn_acc = accuracy_score(y_test, y_knn_pred)
print("Accuracy : %4f" %knn_acc)
# Out:
# Accuracy : 0.695855

# %%
from sklearn.linear_model import LogisticRegression
lrc = LogisticRegression()
lrc.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-1a49d96fef6c> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 lrc = LogisticRegression()
# ----> 3 lrc.fit(X_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1612                 sample_weight=sample_weight,
#    1613             )
# -> 1614             for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1615         )
#    1616
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     810                 jac=True,
#     811                 args=(X, target, 1.0 / C, sample_weight),
# --> 812                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter},
#     813             )
#     814             n_iter_i = _check_optimize_result(
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     622     elif meth == 'l-bfgs-b':
#     623         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 624                                 callback=callback, **options)
#     625     elif meth == 'tnc':
#     626         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     265         if not np.array_equal(x, self.x):
#     266             self._update_x_impl(x)
# --> 267         self._update_fun()
#     268         self._update_grad()
#     269         return self.f, self.g
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in func(x, *args)
#     772
#     773             def func(x, *args):
# --> 774                 return _multinomial_loss_grad(x, *args)[0:2]
#     775
#     776         elif solver == "newton-cg":
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in _multinomial_loss_grad(w, X, Y, alpha, sample_weight)
#     346     fit_intercept = w.size == n_classes * (n_features + 1)
#     347     grad = np.zeros((n_classes, n_features + bool(fit_intercept)), dtype=X.dtype)
# --> 348     loss, p, w = _multinomial_loss(w, X, Y, alpha, sample_weight)
#     349     sample_weight = sample_weight[:, np.newaxis]
#     350     diff = sample_weight * (p - Y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in _multinomial_loss(w, X, Y, alpha, sample_weight)
#     300     loss = -(sample_weight * Y * p).sum()
#     301     loss += 0.5 * alpha * squared_norm(w)
# --> 302     p = np.exp(p, p)
#     303     return loss, p, w
#     304
#
# KeyboardInterrupt:

# %%
#성능 평가
y_lrc_tr_pred = lrc.predict(X_train)
lrc_acc = accuracy_score(y_train, y_lrc_tr_pred)
print("Accuracy : %4f" %lrc_acc)
# Out:
# Accuracy : 0.568791

# %%
#성능 평가
y_lrc_pred = lrc.predict(X_test)
lrc_acc = accuracy_score(y_test, y_lrc_pred)
print("Accuracy : %4f" %lrc_acc)
# Out:
# Accuracy : 0.565499

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier( random_state=20)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=20)

# %%
y_dtc_pred = dtc.predict(X_test)

dtc_acc = accuracy_score(y_test,y_dtc_pred)
print("Accuracy : %4f" %dtc_acc)
# Out:
# Accuracy : 0.633525

# %% [markdown]
# #### 랜덤 포레스트

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=300, random_state = 20)
rfc.fit(X_train, y_train)
#예측
y_rfc_pred = rfc.predict(X_test)

#모델 성능 평가
rfc_acc = accuracy_score(y_test, y_rfc_pred)
print("Accuracy : %4f" %rfc_acc)
# Out:
# Accuracy : 0.646017

# %% [markdown]
# #### 피쳐 중요도

# %%
# tree 계열 알고리즘의 feature importance 그래프
def plot_importance(model, features):
    importances = model.feature_importances_
    indices = np.argsort(importances)
    feature_names = [features[i] for i in indices]
    feature_imp =  importances[indices]

    plt.figure(figsize=(10, 12))
    plt.title('Feature Importances')
    plt.barh(range(len(indices)),feature_imp, align='center')
    plt.yticks(range(len(indices)), feature_names)
    plt.xlabel('Relative Importance')

    print('피처: ', list(reversed(feature_names)))
    print('중요도: ', list(reversed(feature_imp)))

    return list(reversed(feature_names)), list(reversed(feature_imp))

# %%
imp_features, imp_scores = plot_importance(rfc, selected_features)
# Out:
# 피처:  ['AGE_GROUP', 'DSBJT_CD', 'SIDO', 'season', 'SEX']
# 중요도:  [0.4056522043072165, 0.3918307874166348, 0.13502888927555953, 0.03807572404970383, 0.02941239495088541]

# %% [markdown]
# #### 부스팅

# %%
from xgboost import XGBClassifier
xgbc = XGBClassifier(n_estimators=300, random_state=20)
xgbc.fit(X_train,y_train)
#예측
y_xgbc_pred = xgbc.predict(X_test)

xgbc_acc = accuracy_score(y_test, y_xgbc_pred)
print("Accuracy : %4f" %xgbc_acc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-80de291b8fb4> in <module>()
#       1 from xgboost import XGBClassifier
#       2 xgbc = XGBClassifier(n_estimators=300, random_state=20)
# ----> 3 xgbc.fit(X_train,y_train)
#       4 #예측
#       5 y_xgbc_pred = xgbc.predict(X_test)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Kfold

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

kfold = KFold(n_splits=5, shuffle=True, random_state=20)
val_scores = []
num_fold = 1
for tr_idx, val_idx in kfold.split(X_train, y_train):
  X_tr, X_val = X_train.iloc[tr_idx, : ],X_train.iloc[val_idx, :]
  y_tr, y_val = y_train.iloc[tr_idx], y_train.iloc[val_idx]
  #학습
  rfc = RandomForestClassifier(random_state=20)
  rfc.fit(X_tr, y_tr)
  #검증
  y_val_pred = rfc.predict(X_val)
  val_acc = accuracy_score(y_val, y_val_pred)
  print("%d Fold Accuracy: %.4f"%(num_fold, val_acc))
  val_scores.append(val_acc)
  num_fold +=1
# Out:
# 1 Fold Accuracy: 0.7082
# 2 Fold Accuracy: 0.7024
# 3 Fold Accuracy: 0.7028
# 4 Fold Accuracy: 0.7062
# 5 Fold Accuracy: 0.7053

# %% [markdown]
# # 시각화 및 분석

# %%
train['MAIN_SICK'].value_counts().head(50)
# Out:
# I109     141027
# J209      87358
# E119      26401
# J304      22956
# K210      22853
# L239      19240
# K219      17310
# J029      15078
# J0390     15008
# N400      12333
# J060      12138
# B351      12101
# J00       12081
# J303      11814
# N_        11011
# K297      10470
# F_        10104
# M170       9527
# M5456      8892
# M4806      8807
# J0190      8352
# K291       8146
# J040       7785
# J40        7756
# E785       7482
# J069       7153
# A099       7062
# L238       7031
# N185       6537
# A090       6208
# L500       5093
# L249       4838
# B353       4699
# J042       4609
# M511       4545
# J_         4532
# M179       4432
# L209       4351
# J329       4257
# J0100      4099
# K529       4084
# E782       3894
# J459       3771
# E039       3577
# J219       3555
# M171       3520
# S3350      3495
# L309       3473
# J320       3452
# N300       3439
# Name: MAIN_SICK, dtype: int64

# %%
train['desease']=None
train.loc[(train['MAIN_SICK']>"H09")&(train['MAIN_SICK']<"H11"), 'desease']=train['MAIN_SICK']

# %%
train['cold']=0
train.loc[(train['MAIN_SICK']>="J00")&(train['MAIN_SICK']<"J07"), 'cold']=1

# %%
train
# Out:
#          STND_Y  IDV_ID   KEY_SEQ  SEX AGE_GROUP  SIDO RECU_FR_DT  FORM_CD  \
# 0          2020      29   3724043    1    over80    41 2020-12-21        3
# 1          2020      29   3495225    1    over80    41 2020-12-14        3
# 2          2020     255  10615350    2    over80    41 2020-04-20        3
# 3          2020     255  10616553    2    over80    41 2020-04-16        3
# 4          2020    2406   3105303    2    over80    41 2020-12-30        3
# ...         ...     ...       ...  ...       ...   ...        ...      ...
# 1048570    2020  331155  10313767    1     70-79    44 2020-06-25        3
# 1048571    2020  331155  10313766    1     70-79    44 2020-06-24        3
# 1048572    2020  331415   7469843    2     70-79    41 2020-08-27        3
# 1048573    2020  331726  10904243    1     70-79    41 2020-05-08        3
# 1048574    2020  333234   4737765    1    over80    41 2020-10-29        3
#
#          DSBJT_CD MAIN_SICK  ... VSCN  RECN  EDEC_ADD_RT  EDEC_TRAMT  \
# 0               1      I109  ...    1     1         0.15       11540
# 1               1      I109  ...    1     1         0.15       11540
# 2               1      I109  ...    1     1         0.15       11540
# 3               1      I109  ...    1     1         0.15       11540
# 4               1      I109  ...    1     1         0.15       11540
# ...           ...       ...  ...  ...   ...          ...         ...
# 1048570        13      J029  ...    1     1         0.15       16140
# 1048571        13      J029  ...    1     1         0.15       16140
# 1048572        15     N3940  ...    1     1         0.15       16140
# 1048573        15      N400  ...    1     1         0.15       16140
# 1048574         1      J209  ...    1     1         0.15       16140
#
#          EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  DATA_STD_DT month  \
# 0                  1500           10040                0   2021-12-28    12
# 1                  1500           10040                7   2021-12-28    12
# 2                  1500           10040               30   2021-12-28     4
# 3                  1500           10040               30   2021-12-28     4
# 4                  1500           10040                0   2021-12-28    12
# ...                 ...             ...              ...          ...   ...
# 1048570            1600           14540                0   2021-12-28     6
# 1048571            1600           14540                0   2021-12-28     6
# 1048572            1600           14540                7   2021-12-28     8
# 1048573            1600           14540                0   2021-12-28     5
# 1048574            1600           14540                4   2021-12-28    10
#
#          season
# 0        winter
# 1        winter
# 2        spring
# 3        spring
# 4        winter
# ...         ...
# 1048570  summer
# 1048571  summer
# 1048572  summer
# 1048573  spring
# 1048574    fall
#
# [1048575 rows x 21 columns]

# %%
#성별 감기 진료 분포
sns.countplot(x='SEX', hue = 'cold', data = train)
plt.legend(loc='best')

plt.show()

# %%
#계절별 감기 진료 분포
sns.countplot(x = 'season', hue = 'cold', data=train)
plt.legend(loc='best')
plt.show()

# %%
#연령대별 감기 진료 분포
sns.countplot(x='AGE_GROUP', hue = 'cold', data = train)
plt.legend(loc='best')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-86a4a3c1f92a> in <module>()
#       1 #연령대별 감기 진료 분포
# ----> 2 sns.countplot(x='AGE_GROUP', hue = 'cold', data = train)
#       3 plt.legend(loc='best')
#       4
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
#    3603     )
#    3604
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1583         """Initialize the plotter."""
#    1584         self.establish_variables(x, y, hue, data, orient,
# -> 1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#    1587         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'cold'

# %%
train.corr()
# Out:
#                  STND_Y    IDV_ID   KEY_SEQ       SEX  AGE_GROUP      SIDO  \
# STND_Y              NaN       NaN       NaN       NaN        NaN       NaN
# IDV_ID              NaN  1.000000 -0.000710  0.007360  -0.002248 -0.008135
# KEY_SEQ             NaN -0.000710  1.000000  0.001157   0.041256  0.003515
# SEX                 NaN  0.007360  0.001157  1.000000   0.064268 -0.005938
# AGE_GROUP           NaN -0.002248  0.041256  0.064268   1.000000  0.026040
# SIDO                NaN -0.008135  0.003515 -0.005938   0.026040  1.000000
# FORM_CD             NaN -0.008229 -0.006017 -0.002315   0.030778 -0.009057
# DSBJT_CD            NaN -0.000418  0.015068 -0.037223  -0.169632  0.000107
# VSCN                NaN       NaN       NaN       NaN        NaN       NaN
# RECN                NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_ADD_RT         NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_TRAMT          NaN  0.008285  0.011140 -0.034004   0.021291 -0.003666
# EDEC_SBRDN_AMT      NaN  0.012155 -0.006589 -0.030719  -0.321817 -0.018980
# EDEC_JBRDN_AMT      NaN  0.007271  0.013205 -0.032595   0.071993 -0.001127
# TOT_PRES_DD_CNT     NaN  0.000760  0.035243 -0.013911   0.292573 -0.006552
# month               NaN -0.001766  0.198461 -0.001985   0.010832  0.009097
# cold                NaN  0.000621 -0.057520 -0.001304  -0.205122 -0.013005
#
#                   FORM_CD  DSBJT_CD  VSCN  RECN  EDEC_ADD_RT  EDEC_TRAMT  \
# STND_Y                NaN       NaN   NaN   NaN          NaN         NaN
# IDV_ID          -0.008229 -0.000418   NaN   NaN          NaN    0.008285
# KEY_SEQ         -0.006017  0.015068   NaN   NaN          NaN    0.011140
# SEX             -0.002315 -0.037223   NaN   NaN          NaN   -0.034004
# AGE_GROUP        0.030778 -0.169632   NaN   NaN          NaN    0.021291
# SIDO            -0.009057  0.000107   NaN   NaN          NaN   -0.003666
# FORM_CD          1.000000 -0.036197   NaN   NaN          NaN   -0.142735
# DSBJT_CD        -0.036197  1.000000   NaN   NaN          NaN   -0.032867
# VSCN                  NaN       NaN   NaN   NaN          NaN         NaN
# RECN                  NaN       NaN   NaN   NaN          NaN         NaN
# EDEC_ADD_RT           NaN       NaN   NaN   NaN          NaN         NaN
# EDEC_TRAMT      -0.142735 -0.032867   NaN   NaN          NaN    1.000000
# EDEC_SBRDN_AMT  -0.066288  0.041350   NaN   NaN          NaN    0.677834
# EDEC_JBRDN_AMT  -0.146516 -0.042308   NaN   NaN          NaN    0.993783
# TOT_PRES_DD_CNT  0.012387 -0.224793   NaN   NaN          NaN   -0.075644
# month           -0.001338  0.004130   NaN   NaN          NaN    0.007347
# cold             0.005162  0.060425   NaN   NaN          NaN   -0.021589
#
#                  EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT     month  \
# STND_Y                      NaN             NaN              NaN       NaN
# IDV_ID                 0.012155        0.007271         0.000760 -0.001766
# KEY_SEQ               -0.006589        0.013205         0.035243  0.198461
# SEX                   -0.030719       -0.032595        -0.013911 -0.001985
# AGE_GROUP             -0.321817        0.071993         0.292573  0.010832
# SIDO                  -0.018980       -0.001127        -0.006552  0.009097
# FORM_CD               -0.066288       -0.146516         0.012387 -0.001338
# DSBJT_CD               0.041350       -0.042308        -0.224793  0.004130
# VSCN                        NaN             NaN              NaN       NaN
# RECN                        NaN             NaN              NaN       NaN
# EDEC_ADD_RT                 NaN             NaN              NaN       NaN
# EDEC_TRAMT             0.677834        0.993783        -0.075644  0.007347
# EDEC_SBRDN_AMT         1.000000        0.592171        -0.148276 -0.004141
# EDEC_JBRDN_AMT         0.592171        1.000000        -0.060489  0.008670
# TOT_PRES_DD_CNT       -0.148276       -0.060489         1.000000  0.049708
# month                 -0.004141        0.008670         0.049708  1.000000
# cold                   0.052511       -0.031610        -0.166986 -0.045743
#
#                      cold
# STND_Y                NaN
# IDV_ID           0.000621
# KEY_SEQ         -0.057520
# SEX             -0.001304
# AGE_GROUP       -0.205122
# SIDO            -0.013005
# FORM_CD          0.005162
# DSBJT_CD         0.060425
# VSCN                  NaN
# RECN                  NaN
# EDEC_ADD_RT           NaN
# EDEC_TRAMT      -0.021589
# EDEC_SBRDN_AMT   0.052511
# EDEC_JBRDN_AMT  -0.031610
# TOT_PRES_DD_CNT -0.166986
# month           -0.045743
# cold             1.000000

# %%
# 연령대별 단순 진료 분포
sns.countplot(x='AGE_GROUP', hue='SEX',  data=train)

plt.show()

# %%
#계절별 단순 진료 분포
ax=sns.countplot(x = 'season', data=train)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 3, height, ha = 'center', size = 9)
plt.show()

# %%
dasp=train[train['season'].str.contains('spring')]
dasu=train[train['season'].str.contains('summer')]
dafa=train[train['season'].str.contains('fall')]
dawi=train[train['season'].str.contains('winter')]

# %%
dasp['MAIN_SICK'].value_counts().head(10)
# Out:
# I109     34422
# J209     16746
# E119      6489
# K210      5425
# J304      4792
# L239      4691
# K219      4330
# J0390     3039
# N400      3004
# J029      2983
# Name: MAIN_SICK, dtype: int64

# %%
dasu['MAIN_SICK'].value_counts().head(10)
# Out:
# I109     34836
# J209     14600
# E119      6534
# L239      5745
# K210      5520
# J304      4155
# K219      4105
# B351      3807
# J0390     3215
# N400      3109
# Name: MAIN_SICK, dtype: int64

# %%
dafa['MAIN_SICK'].value_counts().head(10)
# Out:
# I109     35776
# J209     19114
# J304      7064
# E119      6733
# K210      5934
# L239      4771
# K219      4462
# J029      3696
# J303      3678
# J0390     3626
# Name: MAIN_SICK, dtype: int64

# %%
dawi['MAIN_SICK'].value_counts().head(10)
# Out:
# J209     36898
# I109     35993
# J304      6945
# E119      6645
# K210      5974
# J029      5432
# J0390     5128
# J00       4563
# J060      4551
# K219      4413
# Name: MAIN_SICK, dtype: int64

# %%
# 주요 질병 10개의 계절별 분포
#dai=train[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400|J060|B351|J00|J303|N_|K297|F_|M170|M5456|M4806')]
dai=train[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400|N185')]
ax=sns.countplot(x = 'MAIN_SICK',hue = 'season', data=dai)
ax.set_title('seasonal distribution of MAIN_SICK')
plt.show()

# %%
# 주요 질병 10 개의 연령별 분포

ax=sns.countplot(x = 'MAIN_SICK',hue = 'AGE_GROUP', data=dai)
plt.legend(loc='best')
ax.set_title('age specific distribution of MAIN_SICK')
#plt.figure(figsize = [10.0,10.0])



plt.show()

# %%
dai
# Out:
#          STND_Y  IDV_ID   KEY_SEQ  SEX AGE_GROUP  SIDO RECU_FR_DT  FORM_CD  \
# 0          2020      29   3724043    1    80over    41 2020-12-21        3
# 1          2020      29   3495225    1    80over    41 2020-12-14        3
# 2          2020     255  10615350    2    80over    41 2020-04-20        3
# 3          2020     255  10616553    2    80over    41 2020-04-16        3
# 4          2020    2406   3105303    2    80over    41 2020-12-30        3
# ...         ...     ...       ...  ...       ...   ...        ...      ...
# 1048569    2020  330771   3388022    2     70-79    41 2020-12-03        3
# 1048570    2020  331155  10313767    1     70-79    44 2020-06-25        3
# 1048571    2020  331155  10313766    1     70-79    44 2020-06-24        3
# 1048573    2020  331726  10904243    1     70-79    41 2020-05-08        3
# 1048574    2020  333234   4737765    1    80over    41 2020-10-29        3
#
#          DSBJT_CD MAIN_SICK  ... VSCN  RECN  EDEC_ADD_RT  EDEC_TRAMT  \
# 0               1      I109  ...    1     1         0.15       11540
# 1               1      I109  ...    1     1         0.15       11540
# 2               1      I109  ...    1     1         0.15       11540
# 3               1      I109  ...    1     1         0.15       11540
# 4               1      I109  ...    1     1         0.15       11540
# ...           ...       ...  ...  ...   ...          ...         ...
# 1048569        13      J029  ...    1     1         0.15       16140
# 1048570        13      J029  ...    1     1         0.15       16140
# 1048571        13      J029  ...    1     1         0.15       16140
# 1048573        15      N400  ...    1     1         0.15       16140
# 1048574         1      J209  ...    1     1         0.15       16140
#
#          EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  DATA_STD_DT month  \
# 0                  1500           10040                0   2021-12-28    12
# 1                  1500           10040                7   2021-12-28    12
# 2                  1500           10040               30   2021-12-28     4
# 3                  1500           10040               30   2021-12-28     4
# 4                  1500           10040                0   2021-12-28    12
# ...                 ...             ...              ...          ...   ...
# 1048569            1600           14540                4   2021-12-28    12
# 1048570            1600           14540                0   2021-12-28     6
# 1048571            1600           14540                0   2021-12-28     6
# 1048573            1600           14540                0   2021-12-28     5
# 1048574            1600           14540                4   2021-12-28    10
#
#          season
# 0        winter
# 1        winter
# 2        spring
# 3        spring
# 4        winter
# ...         ...
# 1048569  winter
# 1048570  summer
# 1048571  summer
# 1048573  spring
# 1048574    fall
#
# [379564 rows x 21 columns]

# %%
# 주요 질병 10 개의 성별 분포

ax=sns.countplot(x = 'MAIN_SICK',hue = 'SEX', data=dai)
plt.legend(loc='best')
ax.set_title('sexual distribution of MAIN_SICK')
plt.show()

# %%
# 원발성 고혈압 연령별 분포
dai.loc[(dai['MAIN_SICK']=="I109"), 'I109']=1
ax=sns.countplot(x = 'I109',hue = 'AGE_GROUP', data=dai)
plt.legend(loc='center left')
ax.set_title('age specific distribution of I109')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# 합병증동반x 2형당뇨병 연령별 분포
dai.loc[(dai['MAIN_SICK']=="E119"), 'E119']=1
ax=sns.countplot(x = 'E119',hue = 'AGE_GROUP', data=dai)
plt.legend(loc='center left')
ax.set_title('age specific distribution of E119')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# 원발성 고혈압 연령별 분포
dai.loc[(dai['MAIN_SICK']=="N185"), 'N185']=1
ax=sns.countplot(x = 'N185',hue = 'AGE_GROUP', data=dai)
plt.legend(loc='center left')
ax.set_title('age specific distribution of E119')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# 앨러지비염 연령별 분포
ax=sns.countplot(x = 'J304',hue = 'AGE_GROUP', data=dai)
plt.legend(loc='center right')
ax.set_title('age specific distribution of J304')
plt.show()

# %%
# 원발성 고혈압 연령별 분포
ax=sns.countplot(x = 'J209',hue = 'AGE_GROUP', data=dai)
plt.legend(loc='center right')
ax.set_title('age specific distribution of J209')
plt.show()

# %%
# 주요 질병 10개의 성별 분포

ax=sns.countplot(x = 'MAIN_SICK',hue = 'SEX', data=dai)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 3, height, ha = 'center', size = 9)
plt.show()
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values

# %%
#계절별 안과질환 분포
sns.countplot(x = 'season', hue = 'desease', data=train)
plt.legend(loc='best')
plt.show()

# %%
#dai['I109']=0
#dai['J209']=0
#dai['E119']=0
#dai['J304']=0
#dai['K210']=0
#dai['L239']=0
#dai['K219']=0
#dai['J029']=0
#dai['J0390']=0
#dai['N400']=0
#dai['J060']=0
#dai['B351']=0
#dai['J00']=0
#dai['J303']=0
#dai['N_']=0
#dai['K297']=0
#dai['F_']=0
#dai['M170']=0
#dai['M5456']=0
#dai['M4806']=0

#dai.loc[(dai['MAIN_SICK']=="I109"), 'I109']=1
#dai.loc[(dai['MAIN_SICK']=="J209"), 'J209']=1
#dai.loc[(dai['MAIN_SICK']=="E119"), 'E119']=1
#dai.loc[(dai['MAIN_SICK']=="J304"), 'J304']=1
#dai.loc[(dai['MAIN_SICK']=="K210"), 'K210']=1
#dai.loc[(dai['MAIN_SICK']=="L239"), 'L239']=1
#dai.loc[(dai['MAIN_SICK']=="K219"), 'K219']=1
#dai.loc[(dai['MAIN_SICK']=="J029"), 'J029']=1
#dai.loc[(dai['MAIN_SICK']=="J0390"), 'J0390']=1
#dai.loc[(dai['MAIN_SICK']=="N400"), 'N400']=1
#dai.loc[(dai['MAIN_SICK']=="J060"), 'J060']=1
#dai.loc[(dai['MAIN_SICK']=="B351"), 'B351']=1
#dai.loc[(dai['MAIN_SICK']=="J00"), 'J00']=1
#dai.loc[(dai['MAIN_SICK']=="J303"), 'J303']=1
#dai.loc[(dai['MAIN_SICK']=="N_"), 'N_']=1
#dai.loc[(dai['MAIN_SICK']=="K297"), 'K297']=1
#dai.loc[(dai['MAIN_SICK']=="F_"), 'F_']=1
#dai.loc[(dai['MAIN_SICK']=="M170"), 'M170']=1
#dai.loc[(dai['MAIN_SICK']=="M5456"), 'M5456']=1
#dai.loc[(dai['MAIN_SICK']=="M4806"), 'M4806']=1
dac=train[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400|J060|B351|J00|J303|N_|K297|F_|M170|M5456|M4806|J0190|K291|J040|J40|E785|J069|A099|L238|N185|A090')]
dac=pd.get_dummies(dac,prefix=None, columns=['MAIN_SICK'])

# %%
dac.corr()
# Out:
#                  STND_Y    IDV_ID   KEY_SEQ       SEX  AGE_GROUP      SIDO  \
# STND_Y              NaN       NaN       NaN       NaN        NaN       NaN
# IDV_ID              NaN  1.000000 -0.002178  0.002351  -0.000460 -0.006234
# KEY_SEQ             NaN -0.002178  1.000000 -0.002204   0.046935  0.005333
# SEX                 NaN  0.002351 -0.002204  1.000000   0.059570 -0.002944
# AGE_GROUP           NaN -0.000460  0.046935  0.059570   1.000000  0.013066
# SIDO                NaN -0.006234  0.005333 -0.002944   0.013066  1.000000
# FORM_CD             NaN       NaN       NaN       NaN        NaN       NaN
# DSBJT_CD            NaN  0.002804  0.003858 -0.036058  -0.198073  0.006294
# VSCN                NaN       NaN       NaN       NaN        NaN       NaN
# RECN                NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_ADD_RT         NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_TRAMT          NaN  0.011700  0.014009 -0.048764   0.037934 -0.009237
# EDEC_SBRDN_AMT      NaN  0.013009 -0.008818 -0.048226  -0.302659 -0.020444
# EDEC_JBRDN_AMT      NaN  0.011120  0.016491 -0.047098   0.081075 -0.007436
# TOT_PRES_DD_CNT     NaN  0.000547  0.063011 -0.024630   0.376223 -0.016208
# month               NaN -0.000467  0.220644 -0.004948   0.008805  0.011182
# MAIN_SICK_A090      NaN -0.004914  0.007599 -0.004666  -0.082110 -0.010622
# MAIN_SICK_A099      NaN  0.000815  0.005951 -0.005049  -0.078301 -0.003960
# MAIN_SICK_B351      NaN  0.000487  0.032117 -0.016251   0.014381  0.001437
# MAIN_SICK_E119      NaN -0.004320  0.024291 -0.021300   0.160140  0.007168
# MAIN_SICK_E785      NaN -0.000164  0.013687  0.025495   0.045942 -0.006603
# MAIN_SICK_F_        NaN  0.002472  0.017844  0.031501   0.091828  0.005970
# MAIN_SICK_I109      NaN -0.001370  0.051763  0.004267   0.356053  0.006550
# MAIN_SICK_J00       NaN  0.002545 -0.026451  0.006009  -0.085407  0.009433
# MAIN_SICK_J0190     NaN  0.001967 -0.019278 -0.011640  -0.128411 -0.000456
# MAIN_SICK_J029      NaN -0.000608 -0.024880  0.007751  -0.105574 -0.012175
# MAIN_SICK_J0390     NaN -0.000104 -0.015489  0.005877  -0.113311 -0.001897
# MAIN_SICK_J040      NaN -0.000729 -0.012391 -0.005114  -0.035993 -0.014443
# MAIN_SICK_J060      NaN  0.000829 -0.026138  0.005582  -0.057963 -0.020556
# MAIN_SICK_J069      NaN  0.000397 -0.020444  0.005077  -0.058602 -0.008343
# MAIN_SICK_J209      NaN  0.001621 -0.113205 -0.001309  -0.309379  0.003275
# MAIN_SICK_J303      NaN -0.000201 -0.009133 -0.013268  -0.107456  0.000761
# MAIN_SICK_J304      NaN -0.003784 -0.010520 -0.017376  -0.163621  0.006791
# MAIN_SICK_J40       NaN -0.001101 -0.033503  0.007216  -0.006022 -0.000556
# MAIN_SICK_K210      NaN -0.001229  0.017684  0.012792   0.032738 -0.003290
# MAIN_SICK_K219      NaN  0.001290  0.018061  0.018121   0.015651 -0.011316
# MAIN_SICK_K291      NaN -0.001989  0.007765  0.013821  -0.010995 -0.009540
# MAIN_SICK_K297      NaN  0.002941  0.009905  0.017953  -0.001858 -0.021282
# MAIN_SICK_L238      NaN -0.000148  0.021461 -0.001371  -0.021213 -0.003618
# MAIN_SICK_L239      NaN -0.002406  0.036857 -0.003906  -0.024429 -0.001042
# MAIN_SICK_M170      NaN -0.002846  0.020746  0.043974   0.103202  0.013969
# MAIN_SICK_M4806     NaN -0.003278  0.018306  0.023838   0.105955  0.007585
# MAIN_SICK_M5456     NaN -0.000500  0.014925  0.001083   0.083676  0.046662
# MAIN_SICK_N185      NaN  0.012286  0.013374 -0.057039   0.054740 -0.009674
# MAIN_SICK_N400      NaN  0.004180  0.014166 -0.168322   0.102699  0.014027
# MAIN_SICK_N_        NaN  0.003740  0.018854  0.105463  -0.043572 -0.010264
#
#                  FORM_CD  DSBJT_CD  VSCN  RECN  ...  MAIN_SICK_K291  \
# STND_Y               NaN       NaN   NaN   NaN  ...             NaN
# IDV_ID               NaN  0.002804   NaN   NaN  ...       -0.001989
# KEY_SEQ              NaN  0.003858   NaN   NaN  ...        0.007765
# SEX                  NaN -0.036058   NaN   NaN  ...        0.013821
# AGE_GROUP            NaN -0.198073   NaN   NaN  ...       -0.010995
# SIDO                 NaN  0.006294   NaN   NaN  ...       -0.009540
# FORM_CD              NaN       NaN   NaN   NaN  ...             NaN
# DSBJT_CD             NaN  1.000000   NaN   NaN  ...       -0.056006
# VSCN                 NaN       NaN   NaN   NaN  ...             NaN
# RECN                 NaN       NaN   NaN   NaN  ...             NaN
# EDEC_ADD_RT          NaN       NaN   NaN   NaN  ...             NaN
# EDEC_TRAMT           NaN -0.038152   NaN   NaN  ...       -0.009388
# EDEC_SBRDN_AMT       NaN  0.040805   NaN   NaN  ...        0.017102
# EDEC_JBRDN_AMT       NaN -0.047127   NaN   NaN  ...       -0.012516
# TOT_PRES_DD_CNT      NaN -0.214040   NaN   NaN  ...       -0.059079
# month                NaN -0.002877   NaN   NaN  ...        0.007794
# MAIN_SICK_A090       NaN -0.040751   NaN   NaN  ...       -0.012863
# MAIN_SICK_A099       NaN -0.031802   NaN   NaN  ...       -0.013730
# MAIN_SICK_B351       NaN  0.081043   NaN   NaN  ...       -0.018055
# MAIN_SICK_E119       NaN -0.112412   NaN   NaN  ...       -0.027024
# MAIN_SICK_E785       NaN -0.050291   NaN   NaN  ...       -0.014138
# MAIN_SICK_F_         NaN -0.029133   NaN   NaN  ...       -0.016468
# MAIN_SICK_I109       NaN -0.272871   NaN   NaN  ...       -0.070485
# MAIN_SICK_J00        NaN  0.028436   NaN   NaN  ...       -0.018040
# MAIN_SICK_J0190      NaN  0.070239   NaN   NaN  ...       -0.014949
# MAIN_SICK_J029       NaN  0.043955   NaN   NaN  ...       -0.020209
# MAIN_SICK_J0390      NaN  0.056879   NaN   NaN  ...       -0.020161
# MAIN_SICK_J040       NaN  0.068954   NaN   NaN  ...       -0.014425
# MAIN_SICK_J060       NaN  0.035175   NaN   NaN  ...       -0.018083
# MAIN_SICK_J069       NaN  0.010825   NaN   NaN  ...       -0.013819
# MAIN_SICK_J209       NaN  0.070412   NaN   NaN  ...       -0.052231
# MAIN_SICK_J303       NaN  0.048562   NaN   NaN  ...       -0.017835
# MAIN_SICK_J304       NaN  0.069951   NaN   NaN  ...       -0.025118
# MAIN_SICK_J40        NaN  0.017217   NaN   NaN  ...       -0.014398
# MAIN_SICK_K210       NaN -0.112095   NaN   NaN  ...       -0.025059
# MAIN_SICK_K219       NaN -0.073781   NaN   NaN  ...       -0.021698
# MAIN_SICK_K291       NaN -0.056006   NaN   NaN  ...        1.000000
# MAIN_SICK_K297       NaN -0.057474   NaN   NaN  ...       -0.016770
# MAIN_SICK_L238       NaN  0.141247   NaN   NaN  ...       -0.013699
# MAIN_SICK_L239       NaN  0.235888   NaN   NaN  ...       -0.022916
# MAIN_SICK_M170       NaN  0.016447   NaN   NaN  ...       -0.015983
# MAIN_SICK_M4806      NaN  0.010294   NaN   NaN  ...       -0.015357
# MAIN_SICK_M5456      NaN  0.022992   NaN   NaN  ...       -0.015432
# MAIN_SICK_N185       NaN -0.046552   NaN   NaN  ...       -0.013203
# MAIN_SICK_N400       NaN  0.201866   NaN   NaN  ...       -0.018231
# MAIN_SICK_N_         NaN  0.115424   NaN   NaN  ...       -0.017206
#
#                  MAIN_SICK_K297  MAIN_SICK_L238  MAIN_SICK_L239  \
# STND_Y                      NaN             NaN             NaN
# IDV_ID                 0.002941       -0.000148       -0.002406
# KEY_SEQ                0.009905        0.021461        0.036857
# SEX                    0.017953       -0.001371       -0.003906
# AGE_GROUP             -0.001858       -0.021213       -0.024429
# SIDO                  -0.021282       -0.003618       -0.001042
# FORM_CD                     NaN             NaN             NaN
# DSBJT_CD              -0.057474        0.141247        0.235888
# VSCN                        NaN             NaN             NaN
# RECN                        NaN             NaN             NaN
# EDEC_ADD_RT                 NaN             NaN             NaN
# EDEC_TRAMT            -0.012125       -0.008267       -0.013571
# EDEC_SBRDN_AMT         0.011389        0.015954        0.022726
# EDEC_JBRDN_AMT        -0.014774       -0.011137       -0.017832
# TOT_PRES_DD_CNT       -0.058459       -0.061844       -0.101726
# month                  0.009034        0.007272        0.016310
# MAIN_SICK_A090        -0.014614       -0.011938       -0.019970
# MAIN_SICK_A099        -0.015599       -0.012743       -0.021316
# MAIN_SICK_B351        -0.020513       -0.016757       -0.028031
# MAIN_SICK_E119        -0.030702       -0.025081       -0.041955
# MAIN_SICK_E785        -0.016062       -0.013121       -0.021949
# MAIN_SICK_F_          -0.018710       -0.015284       -0.025568
# MAIN_SICK_I109        -0.080079       -0.065418       -0.109431
# MAIN_SICK_J00         -0.020495       -0.016743       -0.028008
# MAIN_SICK_J0190       -0.016983       -0.013874       -0.023209
# MAIN_SICK_J029        -0.022960       -0.018756       -0.031375
# MAIN_SICK_J0390       -0.022905       -0.018711       -0.031300
# MAIN_SICK_J040        -0.016388       -0.013388       -0.022395
# MAIN_SICK_J060        -0.020545       -0.016783       -0.028075
# MAIN_SICK_J069        -0.015700       -0.012826       -0.021455
# MAIN_SICK_J209        -0.059340       -0.048476       -0.081090
# MAIN_SICK_J303        -0.020263       -0.016553       -0.027690
# MAIN_SICK_J304        -0.028537       -0.023312       -0.038997
# MAIN_SICK_J40         -0.016357       -0.013363       -0.022353
# MAIN_SICK_K210        -0.028470       -0.023258       -0.038905
# MAIN_SICK_K219        -0.024651       -0.020138       -0.033687
# MAIN_SICK_K291        -0.016770       -0.013699       -0.022916
# MAIN_SICK_K297         1.000000       -0.015564       -0.026035
# MAIN_SICK_L238        -0.015564        1.000000       -0.021269
# MAIN_SICK_L239        -0.026035       -0.021269        1.000000
# MAIN_SICK_M170        -0.018158       -0.014834       -0.024814
# MAIN_SICK_M4806       -0.017447       -0.014253       -0.023842
# MAIN_SICK_M5456       -0.017532       -0.014323       -0.023959
# MAIN_SICK_N185        -0.015001       -0.012254       -0.020499
# MAIN_SICK_N400        -0.020713       -0.016921       -0.028305
# MAIN_SICK_N_          -0.019548       -0.015969       -0.026713
#
#                  MAIN_SICK_M170  MAIN_SICK_M4806  MAIN_SICK_M5456  \
# STND_Y                      NaN              NaN              NaN
# IDV_ID                -0.002846        -0.003278        -0.000500
# KEY_SEQ                0.020746         0.018306         0.014925
# SEX                    0.043974         0.023838         0.001083
# AGE_GROUP              0.103202         0.105955         0.083676
# SIDO                   0.013969         0.007585         0.046662
# FORM_CD                     NaN              NaN              NaN
# DSBJT_CD               0.016447         0.010294         0.022992
# VSCN                        NaN              NaN              NaN
# RECN                        NaN              NaN              NaN
# EDEC_ADD_RT                 NaN              NaN              NaN
# EDEC_TRAMT            -0.003615         0.000872         0.000371
# EDEC_SBRDN_AMT        -0.047617        -0.042199        -0.032138
# EDEC_JBRDN_AMT         0.002188         0.006459         0.004583
# TOT_PRES_DD_CNT       -0.034354        -0.053377        -0.072451
# month                  0.016703         0.013777         0.010771
# MAIN_SICK_A090        -0.013928        -0.013383        -0.013448
# MAIN_SICK_A099        -0.014867        -0.014285        -0.014355
# MAIN_SICK_B351        -0.019550        -0.018785        -0.018877
# MAIN_SICK_E119        -0.029261        -0.028116        -0.028253
# MAIN_SICK_E785        -0.015308        -0.014709        -0.014781
# MAIN_SICK_F_          -0.017832        -0.017134        -0.017218
# MAIN_SICK_I109        -0.076322        -0.073333        -0.073692
# MAIN_SICK_J00         -0.019534        -0.018769        -0.018861
# MAIN_SICK_J0190       -0.016187        -0.015553        -0.015629
# MAIN_SICK_J029        -0.021883        -0.021026        -0.021129
# MAIN_SICK_J0390       -0.021830        -0.020975        -0.021078
# MAIN_SICK_J040        -0.015620        -0.015008        -0.015081
# MAIN_SICK_J060        -0.019581        -0.018814        -0.018906
# MAIN_SICK_J069        -0.014964        -0.014378        -0.014448
# MAIN_SICK_J209        -0.056556        -0.054341        -0.054607
# MAIN_SICK_J303        -0.019312        -0.018556        -0.018647
# MAIN_SICK_J304        -0.027198        -0.026133        -0.026261
# MAIN_SICK_J40         -0.015590        -0.014980        -0.015053
# MAIN_SICK_K210        -0.027134        -0.026072        -0.026199
# MAIN_SICK_K219        -0.023494        -0.022574        -0.022685
# MAIN_SICK_K291        -0.015983        -0.015357        -0.015432
# MAIN_SICK_K297        -0.018158        -0.017447        -0.017532
# MAIN_SICK_L238        -0.014834        -0.014253        -0.014323
# MAIN_SICK_L239        -0.024814        -0.023842        -0.023959
# MAIN_SICK_M170         1.000000        -0.016629        -0.016710
# MAIN_SICK_M4806       -0.016629         1.000000        -0.016056
# MAIN_SICK_M5456       -0.016710        -0.016056         1.000000
# MAIN_SICK_N185        -0.014297        -0.013737        -0.013804
# MAIN_SICK_N400        -0.019741        -0.018968        -0.019061
# MAIN_SICK_N_          -0.018631        -0.017901        -0.017989
#
#                  MAIN_SICK_N185  MAIN_SICK_N400  MAIN_SICK_N_
# STND_Y                      NaN             NaN           NaN
# IDV_ID                 0.012286        0.004180      0.003740
# KEY_SEQ                0.013374        0.014166      0.018854
# SEX                   -0.057039       -0.168322      0.105463
# AGE_GROUP              0.054740        0.102699     -0.043572
# SIDO                  -0.009674        0.014027     -0.010264
# FORM_CD                     NaN             NaN           NaN
# DSBJT_CD              -0.046552        0.201866      0.115424
# VSCN                        NaN             NaN           NaN
# RECN                        NaN             NaN           NaN
# EDEC_ADD_RT                 NaN             NaN           NaN
# EDEC_TRAMT             0.865570       -0.025262     -0.016423
# EDEC_SBRDN_AMT         0.586554       -0.059009      0.024631
# EDEC_JBRDN_AMT         0.871631       -0.019964     -0.021205
# TOT_PRES_DD_CNT       -0.082131        0.116666     -0.021594
# month                  0.008008        0.012825      0.020274
# MAIN_SICK_A090        -0.011506       -0.015888     -0.014994
# MAIN_SICK_A099        -0.012282       -0.016958     -0.016004
# MAIN_SICK_B351        -0.016151       -0.022301     -0.021046
# MAIN_SICK_E119        -0.024173       -0.033378     -0.031500
# MAIN_SICK_E785        -0.012646       -0.017462     -0.016480
# MAIN_SICK_F_          -0.014731       -0.020341     -0.019196
# MAIN_SICK_I109        -0.063050       -0.087059     -0.082162
# MAIN_SICK_J00         -0.016137       -0.022282     -0.021028
# MAIN_SICK_J0190       -0.013372       -0.018464     -0.017425
# MAIN_SICK_J029        -0.018077       -0.024961     -0.023557
# MAIN_SICK_J0390       -0.018034       -0.024902     -0.023501
# MAIN_SICK_J040        -0.012903       -0.017817     -0.016815
# MAIN_SICK_J060        -0.016176       -0.022336     -0.021079
# MAIN_SICK_J069        -0.012361       -0.017069     -0.016109
# MAIN_SICK_J209        -0.046721       -0.064512     -0.060883
# MAIN_SICK_J303        -0.015954       -0.022029     -0.020790
# MAIN_SICK_J304        -0.022468       -0.031024     -0.029279
# MAIN_SICK_J40         -0.012879       -0.017783     -0.016783
# MAIN_SICK_K210        -0.022416       -0.030952     -0.029211
# MAIN_SICK_K219        -0.019409       -0.026800     -0.025292
# MAIN_SICK_K291        -0.013203       -0.018231     -0.017206
# MAIN_SICK_K297        -0.015001       -0.020713     -0.019548
# MAIN_SICK_L238        -0.012254       -0.016921     -0.015969
# MAIN_SICK_L239        -0.020499       -0.028305     -0.026713
# MAIN_SICK_M170        -0.014297       -0.019741     -0.018631
# MAIN_SICK_M4806       -0.013737       -0.018968     -0.017901
# MAIN_SICK_M5456       -0.013804       -0.019061     -0.017989
# MAIN_SICK_N185         1.000000       -0.016308     -0.015391
# MAIN_SICK_N400        -0.016308        1.000000     -0.021252
# MAIN_SICK_N_          -0.015391       -0.021252      1.000000
#
# [46 rows x 46 columns]
