# %% [markdown]
# # 환경 설정

# %%
# 라이브러리 설정
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터셋 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#CSV파일을 읽어오기
drive_path = "/content/drive/MyDrive/"

train = pd.read_csv(drive_path + "dataset1.csv")

print(train.shape)
# Out:
# (1048575, 19)

# %% [markdown]
# # 데이터 살펴보기

# %% [markdown]
# ### 데이터 구조

# %%
# train 데이터프레임 내용 확인
train.head(3)
# Out:
#    STND_Y  IDV_ID   KEY_SEQ  SEX  AGE_GROUP  SIDO RECU_FR_DT  FORM_CD  \
# 0    2020      29   3724043    1         17    41 2020-12-21        3
# 1    2020      29   3495225    1         17    41 2020-12-14        3
# 2    2020     255  10615350    2         18    41 2020-04-20        3
#
#    DSBJT_CD MAIN_SICK  ... VSCN  RECN  EDEC_ADD_RT  EDEC_TRAMT  \
# 0         1      I109  ...    1     1         0.15       11540
# 1         1      I109  ...    1     1         0.15       11540
# 2         1      I109  ...    1     1         0.15       11540
#
#    EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  DATA_STD_DT month  season
# 0            1500           10040                0   2021-12-28    12       4
# 1            1500           10040                7   2021-12-28    12       4
# 2            1500           10040               30   2021-12-28     4       1
#
# [3 rows x 21 columns]

# %%
# train 데이터프레임 개요 정보
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   STND_Y           1048575 non-null  int64
#  1   IDV_ID           1048575 non-null  int64
#  2   KEY_SEQ          1048575 non-null  int64
#  3   SEX              1048575 non-null  int64
#  4   AGE_GROUP        1048575 non-null  int64
#  5   SIDO             1048575 non-null  int64
#  6   RECU_FR_DT       1048575 non-null  datetime64[ns]
#  7   FORM_CD          1048575 non-null  int64
#  8   DSBJT_CD         1048575 non-null  int64
#  9   MAIN_SICK        1048575 non-null  object
#  10  SUB_SICK         1048575 non-null  object
#  11  VSCN             1048575 non-null  int64
#  12  RECN             1048575 non-null  int64
#  13  EDEC_ADD_RT      1048575 non-null  float64
#  14  EDEC_TRAMT       1048575 non-null  int64
#  15  EDEC_SBRDN_AMT   1048575 non-null  int64
#  16  EDEC_JBRDN_AMT   1048575 non-null  int64
#  17  TOT_PRES_DD_CNT  1048575 non-null  int64
#  18  DATA_STD_DT      1048575 non-null  object
#  19  month            1048575 non-null  int64
#  20  season           1048575 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(16), object(3)
# memory usage: 168.0+ MB

# %%
# train 데이터프레임 통계정보
train.describe(include='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#            STND_Y        IDV_ID       KEY_SEQ           SEX     AGE_GROUP  \
# count   1048575.0  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# unique        NaN           NaN           NaN           NaN           NaN
# top           NaN           NaN           NaN           NaN           NaN
# freq          NaN           NaN           NaN           NaN           NaN
# first         NaN           NaN           NaN           NaN           NaN
# last          NaN           NaN           NaN           NaN           NaN
# mean       2020.0  1.661755e+05  5.659551e+06  1.562559e+00  1.123280e+01
# std           0.0  9.611398e+04  3.406616e+06  4.960712e-01  4.770835e+00
# min        2020.0  2.000000e+00  1.000000e+01  1.000000e+00  1.000000e+00
# 25%        2020.0  8.318050e+04  2.617641e+06  1.000000e+00  8.000000e+00
# 50%        2020.0  1.662400e+05  5.558405e+06  2.000000e+00  1.200000e+01
# 75%        2020.0  2.491910e+05  8.592534e+06  2.000000e+00  1.500000e+01
# max        2020.0  3.333330e+05  1.172724e+07  2.000000e+00  1.800000e+01
#
#                 SIDO           RECU_FR_DT       FORM_CD      DSBJT_CD  \
# count   1.048575e+06              1048575  1.048575e+06  1.048575e+06
# unique           NaN                  366           NaN           NaN
# top              NaN  2020-01-28 00:00:00           NaN           NaN
# freq             NaN                 7005           NaN           NaN
# first            NaN  2020-01-01 00:00:00           NaN           NaN
# last             NaN  2020-12-31 00:00:00           NaN           NaN
# mean    3.369546e+01                  NaN  2.999735e+00  6.451292e+00
# std     1.278442e+01                  NaN  1.628041e-02  6.457953e+00
# min     1.100000e+01                  NaN  2.000000e+00  0.000000e+00
# 25%     2.700000e+01                  NaN  3.000000e+00  1.000000e+00
# 50%     4.100000e+01                  NaN  3.000000e+00  4.000000e+00
# 75%     4.400000e+01                  NaN  3.000000e+00  1.300000e+01
# max     4.900000e+01                  NaN  3.000000e+00  5.500000e+01
#
#        MAIN_SICK  ...       VSCN       RECN   EDEC_ADD_RT    EDEC_TRAMT  \
# count    1048575  ...  1048575.0  1048575.0  1.048575e+06  1.048575e+06
# unique      4169  ...        NaN        NaN           NaN           NaN
# top         I109  ...        NaN        NaN           NaN           NaN
# freq      141027  ...        NaN        NaN           NaN           NaN
# first        NaN  ...        NaN        NaN           NaN           NaN
# last         NaN  ...        NaN        NaN           NaN           NaN
# mean         NaN  ...        1.0        1.0  1.500000e-01  1.549178e+04
# std          NaN  ...        0.0        0.0  2.775559e-17  1.828412e+04
# min          NaN  ...        1.0        1.0  1.500000e-01  1.530000e+03
# 25%          NaN  ...        1.0        1.0  1.500000e-01  1.154000e+04
# 50%          NaN  ...        1.0        1.0  1.500000e-01  1.362000e+04
# 75%          NaN  ...        1.0        1.0  1.500000e-01  1.614000e+04
# max          NaN  ...        1.0        1.0  1.500000e-01  3.278950e+06
#
#         EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  DATA_STD_DT  \
# count     1.048575e+06    1.048575e+06     1.048575e+06      1048575
# unique             NaN             NaN              NaN            1
# top                NaN             NaN              NaN   2021-12-28
# freq               NaN             NaN              NaN      1048575
# first              NaN             NaN              NaN          NaN
# last               NaN             NaN              NaN          NaN
# mean      3.198712e+03    1.229186e+04     1.467077e+01          NaN
# std       2.523003e+03    1.667087e+04     1.926278e+01          NaN
# min       0.000000e+00    3.000000e+01     0.000000e+00          NaN
# 25%       1.500000e+03    9.620000e+03     3.000000e+00          NaN
# 50%       3.400000e+03    1.083000e+04     5.000000e+00          NaN
# 75%       4.200000e+03    1.212000e+04     3.000000e+01          NaN
# max       3.517000e+05    2.951150e+06     3.650000e+02          NaN
#
#                month        season
# count   1.048575e+06  1.048575e+06
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean    6.340186e+00  2.589259e+00
# std     3.564714e+00  1.125482e+00
# min     1.000000e+00  1.000000e+00
# 25%     3.000000e+00  2.000000e+00
# 50%     6.000000e+00  3.000000e+00
# 75%     9.000000e+00  4.000000e+00
# max     1.200000e+01  4.000000e+00
#
# [13 rows x 21 columns]

# %% [markdown]
# ### 결측값 확인

# %%
# 결측값 분포
import missingno as msno
msno.bar(train, figsize=(10, 5), color=(0.7, 0.2, 0.2))
plt.show()

# %%
# 중복 데이터 확인
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# # 피처 엔지니어링
# - 문자열, 범주형 변수를 포함
# - 데이터 탐색(EDA) 및 전처리(pre-processing) 포함

# %%
train['RECU_FR_DT'] = pd.to_datetime(train['RECU_FR_DT'])
train['month']=train['RECU_FR_DT'].dt.month
train['season'] = 4
train.loc[train['month']<12, 'season']=3
train.loc[train['month']<9, 'season']=2
train.loc[train['month']<6, 'season']=1
train.loc[(train['month']==1)| (train['month']==2), 'season']=4

# %%
df=train.loc[:,['SEX','AGE_GROUP','MAIN_SICK','season','DSBJT_CD']]

# %%
#df=df[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400|J060|B351|J00|J303|N_|K297|F_|M170|M5456|M4806|J0190|K291|J040|J40|E785|J069|A099|L238|N185|A090|L500|L249|B353|J042|M511|J_|M179|L209|J329|J0100|K529|E782|J459|E039|J219|M171|S3350|L309|J320|N300')]
df=df[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400|J060|B351|J00|J303|N_|K297|F_|M170|M5456|M4806|J0190|K291|J040|J40|E785|J069|A099|L238|N185|A090')]

# %%
df
# Out:
#          SEX  AGE_GROUP MAIN_SICK  season  DSBJT_CD
# 0          1         17      I109       4         1
# 1          1         17      I109       4         1
# 2          2         18      I109       1         1
# 3          2         18      I109       1         1
# 4          2         17      I109       4         1
# ...      ...        ...       ...     ...       ...
# 1048569    2         15      J029       4        13
# 1048570    1         15      J029       2        13
# 1048571    1         15      J029       2        13
# 1048573    1         16      N400       1        15
# 1048574    1         17      J209       3         1
#
# [560021 rows x 5 columns]

# %% [markdown]
# ### 숨기기

# %%
train['desease']=None
train.loc[(train['MAIN_SICK']>"H09")&(train['MAIN_SICK']<"H11"), 'desease']=train['MAIN_SICK']

# %%
train['cold']=0
train.loc[(train['MAIN_SICK']>="J00")&(train['MAIN_SICK']<"J07"), 'cold']=1

# %%
train
# Out:
#          STND_Y  IDV_ID   KEY_SEQ  SEX  AGE_GROUP  SIDO RECU_FR_DT  FORM_CD  \
# 0          2020      29   3724043    1         17    41 2020-12-21        3
# 1          2020      29   3495225    1         17    41 2020-12-14        3
# 2          2020     255  10615350    2         18    41 2020-04-20        3
# 3          2020     255  10616553    2         18    41 2020-04-16        3
# 4          2020    2406   3105303    2         17    41 2020-12-30        3
# ...         ...     ...       ...  ...        ...   ...        ...      ...
# 1048570    2020  331155  10313767    1         15    44 2020-06-25        3
# 1048571    2020  331155  10313766    1         15    44 2020-06-24        3
# 1048572    2020  331415   7469843    2         16    41 2020-08-27        3
# 1048573    2020  331726  10904243    1         16    41 2020-05-08        3
# 1048574    2020  333234   4737765    1         17    41 2020-10-29        3
#
#          DSBJT_CD MAIN_SICK  ... EDEC_ADD_RT  EDEC_TRAMT  EDEC_SBRDN_AMT  \
# 0               1      I109  ...        0.15       11540            1500
# 1               1      I109  ...        0.15       11540            1500
# 2               1      I109  ...        0.15       11540            1500
# 3               1      I109  ...        0.15       11540            1500
# 4               1      I109  ...        0.15       11540            1500
# ...           ...       ...  ...         ...         ...             ...
# 1048570        13      J029  ...        0.15       16140            1600
# 1048571        13      J029  ...        0.15       16140            1600
# 1048572        15     N3940  ...        0.15       16140            1600
# 1048573        15      N400  ...        0.15       16140            1600
# 1048574         1      J209  ...        0.15       16140            1600
#
#          EDEC_JBRDN_AMT  TOT_PRES_DD_CNT  DATA_STD_DT  month  season desease  \
# 0                 10040                0   2021-12-28     12  winter    None
# 1                 10040                7   2021-12-28     12  winter    None
# 2                 10040               30   2021-12-28      4  spring    None
# 3                 10040               30   2021-12-28      4  spring    None
# 4                 10040                0   2021-12-28     12  winter    None
# ...                 ...              ...          ...    ...     ...     ...
# 1048570           14540                0   2021-12-28      6  summer    None
# 1048571           14540                0   2021-12-28      6  summer    None
# 1048572           14540                7   2021-12-28      8  summer    None
# 1048573           14540                0   2021-12-28      5  spring    None
# 1048574           14540                4   2021-12-28     10    fall    None
#
#          cold
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 1048570     1
# 1048571     1
# 1048572     0
# 1048573     0
# 1048574     0
#
# [1048575 rows x 23 columns]

# %%
#성별 감기 진료 분포
sns.countplot(x='SEX', hue = 'cold', data = train)
plt.legend(loc='best')

plt.show()

# %%
#계절별 감기 진료 분포
sns.countplot(x = 'season', hue = 'cold', data=train)
plt.legend(loc='best')
plt.show()

# %%
#연령대별 감기 진료 분포
sns.countplot(x='AGE_GROUP', hue = 'cold', data = train)
plt.legend(loc='best')

plt.show()

# %%
train.corr()
# Out:
#                  STND_Y    IDV_ID   KEY_SEQ       SEX  AGE_GROUP      SIDO  \
# STND_Y              NaN       NaN       NaN       NaN        NaN       NaN
# IDV_ID              NaN  1.000000 -0.000710  0.007360  -0.002248 -0.008135
# KEY_SEQ             NaN -0.000710  1.000000  0.001157   0.041256  0.003515
# SEX                 NaN  0.007360  0.001157  1.000000   0.064268 -0.005938
# AGE_GROUP           NaN -0.002248  0.041256  0.064268   1.000000  0.026040
# SIDO                NaN -0.008135  0.003515 -0.005938   0.026040  1.000000
# FORM_CD             NaN -0.008229 -0.006017 -0.002315   0.030778 -0.009057
# DSBJT_CD            NaN -0.000418  0.015068 -0.037223  -0.169632  0.000107
# VSCN                NaN       NaN       NaN       NaN        NaN       NaN
# RECN                NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_ADD_RT         NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_TRAMT          NaN  0.008285  0.011140 -0.034004   0.021291 -0.003666
# EDEC_SBRDN_AMT      NaN  0.012155 -0.006589 -0.030719  -0.321817 -0.018980
# EDEC_JBRDN_AMT      NaN  0.007271  0.013205 -0.032595   0.071993 -0.001127
# TOT_PRES_DD_CNT     NaN  0.000760  0.035243 -0.013911   0.292573 -0.006552
# month               NaN -0.001766  0.198461 -0.001985   0.010832  0.009097
# cold                NaN  0.000621 -0.057520 -0.001304  -0.205122 -0.013005
#
#                   FORM_CD  DSBJT_CD  VSCN  RECN  EDEC_ADD_RT  EDEC_TRAMT  \
# STND_Y                NaN       NaN   NaN   NaN          NaN         NaN
# IDV_ID          -0.008229 -0.000418   NaN   NaN          NaN    0.008285
# KEY_SEQ         -0.006017  0.015068   NaN   NaN          NaN    0.011140
# SEX             -0.002315 -0.037223   NaN   NaN          NaN   -0.034004
# AGE_GROUP        0.030778 -0.169632   NaN   NaN          NaN    0.021291
# SIDO            -0.009057  0.000107   NaN   NaN          NaN   -0.003666
# FORM_CD          1.000000 -0.036197   NaN   NaN          NaN   -0.142735
# DSBJT_CD        -0.036197  1.000000   NaN   NaN          NaN   -0.032867
# VSCN                  NaN       NaN   NaN   NaN          NaN         NaN
# RECN                  NaN       NaN   NaN   NaN          NaN         NaN
# EDEC_ADD_RT           NaN       NaN   NaN   NaN          NaN         NaN
# EDEC_TRAMT      -0.142735 -0.032867   NaN   NaN          NaN    1.000000
# EDEC_SBRDN_AMT  -0.066288  0.041350   NaN   NaN          NaN    0.677834
# EDEC_JBRDN_AMT  -0.146516 -0.042308   NaN   NaN          NaN    0.993783
# TOT_PRES_DD_CNT  0.012387 -0.224793   NaN   NaN          NaN   -0.075644
# month           -0.001338  0.004130   NaN   NaN          NaN    0.007347
# cold             0.005162  0.060425   NaN   NaN          NaN   -0.021589
#
#                  EDEC_SBRDN_AMT  EDEC_JBRDN_AMT  TOT_PRES_DD_CNT     month  \
# STND_Y                      NaN             NaN              NaN       NaN
# IDV_ID                 0.012155        0.007271         0.000760 -0.001766
# KEY_SEQ               -0.006589        0.013205         0.035243  0.198461
# SEX                   -0.030719       -0.032595        -0.013911 -0.001985
# AGE_GROUP             -0.321817        0.071993         0.292573  0.010832
# SIDO                  -0.018980       -0.001127        -0.006552  0.009097
# FORM_CD               -0.066288       -0.146516         0.012387 -0.001338
# DSBJT_CD               0.041350       -0.042308        -0.224793  0.004130
# VSCN                        NaN             NaN              NaN       NaN
# RECN                        NaN             NaN              NaN       NaN
# EDEC_ADD_RT                 NaN             NaN              NaN       NaN
# EDEC_TRAMT             0.677834        0.993783        -0.075644  0.007347
# EDEC_SBRDN_AMT         1.000000        0.592171        -0.148276 -0.004141
# EDEC_JBRDN_AMT         0.592171        1.000000        -0.060489  0.008670
# TOT_PRES_DD_CNT       -0.148276       -0.060489         1.000000  0.049708
# month                 -0.004141        0.008670         0.049708  1.000000
# cold                   0.052511       -0.031610        -0.166986 -0.045743
#
#                      cold
# STND_Y                NaN
# IDV_ID           0.000621
# KEY_SEQ         -0.057520
# SEX             -0.001304
# AGE_GROUP       -0.205122
# SIDO            -0.013005
# FORM_CD          0.005162
# DSBJT_CD         0.060425
# VSCN                  NaN
# RECN                  NaN
# EDEC_ADD_RT           NaN
# EDEC_TRAMT      -0.021589
# EDEC_SBRDN_AMT   0.052511
# EDEC_JBRDN_AMT  -0.031610
# TOT_PRES_DD_CNT -0.166986
# month           -0.045743
# cold             1.000000

# %%
# 연령대별 단순 진료 분포
sns.countplot(x='AGE_GROUP', hue='SEX',  data=train)

plt.show()

# %%
#계절별 단순 진료 분포
ax=sns.countplot(x = 'season', data=train)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 3, height, ha = 'center', size = 9)
plt.show()

# %%
train['MAIN_SICK'].value_counts().head(50)
# Out:
# I109     141027
# J209      87358
# E119      26401
# J304      22956
# K210      22853
# L239      19240
# K219      17310
# J029      15078
# J0390     15008
# N400      12333
# J060      12138
# B351      12101
# J00       12081
# J303      11814
# N_        11011
# K297      10470
# F_        10104
# M170       9527
# M5456      8892
# M4806      8807
# J0190      8352
# K291       8146
# J040       7785
# J40        7756
# E785       7482
# J069       7153
# A099       7062
# L238       7031
# N185       6537
# A090       6208
# L500       5093
# L249       4838
# B353       4699
# J042       4609
# M511       4545
# J_         4532
# M179       4432
# L209       4351
# J329       4257
# J0100      4099
# K529       4084
# E782       3894
# J459       3771
# E039       3577
# J219       3555
# M171       3520
# S3350      3495
# L309       3473
# J320       3452
# N300       3439
# Name: MAIN_SICK, dtype: int64

# %%
dasp=train[train['season'].str.contains('spring')]
dasu=train[train['season'].str.contains('summer')]
dafa=train[train['season'].str.contains('fall')]
dawi=train[train['season'].str.contains('winter')]

# %%
dasp['MAIN_SICK'].value_counts().head(10)
# Out:
# I109     34422
# J209     16746
# E119      6489
# K210      5425
# J304      4792
# L239      4691
# K219      4330
# J0390     3039
# N400      3004
# J029      2983
# Name: MAIN_SICK, dtype: int64

# %%
dasu['MAIN_SICK'].value_counts().head(10)
# Out:
# I109     34836
# J209     14600
# E119      6534
# L239      5745
# K210      5520
# J304      4155
# K219      4105
# B351      3807
# J0390     3215
# N400      3109
# Name: MAIN_SICK, dtype: int64

# %%
dafa['MAIN_SICK'].value_counts().head(10)
# Out:
# I109     35776
# J209     19114
# J304      7064
# E119      6733
# K210      5934
# L239      4771
# K219      4462
# J029      3696
# J303      3678
# J0390     3626
# Name: MAIN_SICK, dtype: int64

# %%
dawi['MAIN_SICK'].value_counts().head(10)
# Out:
# J209     36898
# I109     35993
# J304      6945
# E119      6645
# K210      5974
# J029      5432
# J0390     5128
# J00       4563
# J060      4551
# K219      4413
# Name: MAIN_SICK, dtype: int64

# %%
# 주요 질병 10개의 계절별 분포
dai=train[train['MAIN_SICK'].str.contains('I109|J209|E119|J304|K210|L239|K219|J029|J0390|N400')]
ax=sns.countplot(x = 'MAIN_SICK',hue = 'season', data=dai)

plt.show()

# %%
dai['I109']=0
dai['J209']=0
dai['E119']=0
dai['J304']=0
dai['K210']=0
dai['L239']=0
dai['K219']=0
dai['J029']=0
dai['J0390']=0
dai['N400']=0

dai.loc[(dai['MAIN_SICK']=="I109"), 'I109']=1
dai.loc[(dai['MAIN_SICK']=="J209"), 'J209']=1
dai.loc[(dai['MAIN_SICK']=="E119"), 'E119']=1
dai.loc[(dai['MAIN_SICK']=="J304"), 'J304']=1
dai.loc[(dai['MAIN_SICK']=="K210"), 'K210']=1
dai.loc[(dai['MAIN_SICK']=="L239"), 'L239']=1
dai.loc[(dai['MAIN_SICK']=="K219"), 'K219']=1
dai.loc[(dai['MAIN_SICK']=="J029"), 'J029']=1
dai.loc[(dai['MAIN_SICK']=="J0390"), 'J0390']=1
dai.loc[(dai['MAIN_SICK']=="N400"), 'N400']=1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
dai
# Out:
#          STND_Y  IDV_ID   KEY_SEQ  SEX  AGE_GROUP  SIDO RECU_FR_DT  FORM_CD  \
# 0          2020      29   3724043    1         17    41 2020-12-21        3
# 1          2020      29   3495225    1         17    41 2020-12-14        3
# 2          2020     255  10615350    2         18    41 2020-04-20        3
# 3          2020     255  10616553    2         18    41 2020-04-16        3
# 4          2020    2406   3105303    2         17    41 2020-12-30        3
# ...         ...     ...       ...  ...        ...   ...        ...      ...
# 1048569    2020  330771   3388022    2         15    41 2020-12-03        3
# 1048570    2020  331155  10313767    1         15    44 2020-06-25        3
# 1048571    2020  331155  10313766    1         15    44 2020-06-24        3
# 1048573    2020  331726  10904243    1         16    41 2020-05-08        3
# 1048574    2020  333234   4737765    1         17    41 2020-10-29        3
#
#          DSBJT_CD MAIN_SICK  ... I109  J209  E119  J304  K210  L239  K219  \
# 0               1      I109  ...    1     0     0     0     0     0     0
# 1               1      I109  ...    1     0     0     0     0     0     0
# 2               1      I109  ...    1     0     0     0     0     0     0
# 3               1      I109  ...    1     0     0     0     0     0     0
# 4               1      I109  ...    1     0     0     0     0     0     0
# ...           ...       ...  ...  ...   ...   ...   ...   ...   ...   ...
# 1048569        13      J029  ...    0     0     0     0     0     0     0
# 1048570        13      J029  ...    0     0     0     0     0     0     0
# 1048571        13      J029  ...    0     0     0     0     0     0     0
# 1048573        15      N400  ...    0     0     0     0     0     0     0
# 1048574         1      J209  ...    0     1     0     0     0     0     0
#
#          J029 J0390  N400
# 0           0     0     0
# 1           0     0     0
# 2           0     0     0
# 3           0     0     0
# 4           0     0     0
# ...       ...   ...   ...
# 1048569     1     0     0
# 1048570     1     0     0
# 1048571     1     0     0
# 1048573     0     0     1
# 1048574     0     0     0
#
# [379564 rows x 33 columns]

# %%
dai.corr()
# Out:
#                  STND_Y    IDV_ID   KEY_SEQ       SEX  AGE_GROUP      SIDO  \
# STND_Y              NaN       NaN       NaN       NaN        NaN       NaN
# IDV_ID              NaN  1.000000 -0.003200 -0.001006   0.000142 -0.004960
# KEY_SEQ             NaN -0.003200  1.000000 -0.003572   0.056783  0.004161
# SEX                 NaN -0.001006 -0.003572  1.000000   0.055660 -0.002427
# AGE_GROUP           NaN  0.000142  0.056783  0.055660   1.000000 -0.000604
# SIDO                NaN -0.004960  0.004161 -0.002427  -0.000604  1.000000
# FORM_CD             NaN       NaN       NaN       NaN        NaN       NaN
# DSBJT_CD            NaN -0.000343 -0.001990 -0.064155  -0.225072  0.008941
# VSCN                NaN       NaN       NaN       NaN        NaN       NaN
# RECN                NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_ADD_RT         NaN       NaN       NaN       NaN        NaN       NaN
# EDEC_TRAMT          NaN  0.001735  0.003104  0.010294  -0.078123 -0.004428
# EDEC_SBRDN_AMT      NaN  0.001964 -0.037022 -0.028038  -0.549622 -0.016491
# EDEC_JBRDN_AMT      NaN  0.000855  0.026564  0.029897   0.243648  0.004856
# TOT_PRES_DD_CNT     NaN  0.002406  0.081591 -0.037584   0.435515 -0.028552
# month               NaN -0.001384  0.225010 -0.007568   0.019382  0.009726
# cold                NaN  0.000078 -0.032667  0.022402  -0.205674 -0.014178
# I109                NaN  0.000035  0.075907  0.032911   0.440295  0.004299
# J209                NaN  0.003367 -0.138155  0.017737  -0.416627  0.001041
# E119                NaN -0.004636  0.032438 -0.016394   0.185639  0.007278
# J304                NaN -0.004018 -0.010384 -0.012251  -0.211555  0.006912
# K210                NaN -0.000896  0.024108  0.024623   0.029666 -0.005511
# L239                NaN -0.002382  0.047268  0.003428  -0.039583 -0.002611
# K219                NaN  0.002098  0.024175  0.029857   0.010067 -0.015169
# J029                NaN -0.000252 -0.028332  0.016660  -0.137684 -0.016122
# J0390               NaN  0.000361 -0.016890  0.014358  -0.147128 -0.003496
# N400                NaN  0.005526  0.019037 -0.198351   0.117901  0.016152
#
#                  FORM_CD  DSBJT_CD  VSCN  RECN  ...      I109      J209  \
# STND_Y               NaN       NaN   NaN   NaN  ...       NaN       NaN
# IDV_ID               NaN -0.000343   NaN   NaN  ...  0.000035  0.003367
# KEY_SEQ              NaN -0.001990   NaN   NaN  ...  0.075907 -0.138155
# SEX                  NaN -0.064155   NaN   NaN  ...  0.032911  0.017737
# AGE_GROUP            NaN -0.225072   NaN   NaN  ...  0.440295 -0.416627
# SIDO                 NaN  0.008941   NaN   NaN  ...  0.004299  0.001041
# FORM_CD              NaN       NaN   NaN   NaN  ...       NaN       NaN
# DSBJT_CD             NaN  1.000000   NaN   NaN  ... -0.306363  0.129090
# VSCN                 NaN       NaN   NaN   NaN  ...       NaN       NaN
# RECN                 NaN       NaN   NaN   NaN  ...       NaN       NaN
# EDEC_ADD_RT          NaN       NaN   NaN   NaN  ...       NaN       NaN
# EDEC_TRAMT           NaN  0.012378   NaN   NaN  ... -0.029983  0.008811
# EDEC_SBRDN_AMT       NaN  0.117704   NaN   NaN  ... -0.253686  0.170757
# EDEC_JBRDN_AMT       NaN -0.057543   NaN   NaN  ...  0.119811 -0.094508
# TOT_PRES_DD_CNT      NaN -0.237470   NaN   NaN  ...  0.614506 -0.424766
# month                NaN -0.009430   NaN   NaN  ...  0.071209 -0.129522
# cold                 NaN  0.110267   NaN   NaN  ... -0.225603 -0.160428
# I109                 NaN -0.306363   NaN   NaN  ...  1.000000 -0.420417
# J209                 NaN  0.129090   NaN   NaN  ... -0.420417  1.000000
# E119                 NaN -0.118526   NaN   NaN  ... -0.210231 -0.149496
# J304                 NaN  0.104220   NaN   NaN  ... -0.195086 -0.138726
# K210                 NaN -0.119370   NaN   NaN  ... -0.194620 -0.138395
# L239                 NaN  0.305855   NaN   NaN  ... -0.177676 -0.126346
# K219                 NaN -0.074583   NaN   NaN  ... -0.168080 -0.119522
# J029                 NaN  0.068466   NaN   NaN  ... -0.156388 -0.111209
# J0390                NaN  0.084242   NaN   NaN  ... -0.156010 -0.110939
# N400                 NaN  0.259917   NaN   NaN  ... -0.140909 -0.100201
#
#                      E119      J304      K210      L239      K219      J029  \
# STND_Y                NaN       NaN       NaN       NaN       NaN       NaN
# IDV_ID          -0.004636 -0.004018 -0.000896 -0.002382  0.002098 -0.000252
# KEY_SEQ          0.032438 -0.010384  0.024108  0.047268  0.024175 -0.028332
# SEX             -0.016394 -0.012251  0.024623  0.003428  0.029857  0.016660
# AGE_GROUP        0.185639 -0.211555  0.029666 -0.039583  0.010067 -0.137684
# SIDO             0.007278  0.006912 -0.005511 -0.002611 -0.015169 -0.016122
# FORM_CD               NaN       NaN       NaN       NaN       NaN       NaN
# DSBJT_CD        -0.118526  0.104220 -0.119370  0.305855 -0.074583  0.068466
# VSCN                  NaN       NaN       NaN       NaN       NaN       NaN
# RECN                  NaN       NaN       NaN       NaN       NaN       NaN
# EDEC_ADD_RT           NaN       NaN       NaN       NaN       NaN       NaN
# EDEC_TRAMT       0.021289  0.019172 -0.040004  0.045680 -0.008357  0.042124
# EDEC_SBRDN_AMT  -0.164212  0.112225  0.040991  0.083525  0.047176  0.103450
# EDEC_JBRDN_AMT   0.127134 -0.045834 -0.073910  0.004101 -0.039220 -0.012497
# TOT_PRES_DD_CNT  0.149401 -0.170367 -0.070227 -0.159383 -0.091584 -0.160841
# month            0.025330  0.011729  0.028022  0.021887  0.019085 -0.023013
# cold            -0.080222 -0.074443 -0.074265 -0.067800 -0.064138  0.693201
# I109            -0.210231 -0.195086 -0.194620 -0.177676 -0.168080 -0.156388
# J209            -0.149496 -0.138726 -0.138395 -0.126346 -0.119522 -0.111209
# E119             1.000000 -0.069371 -0.069205 -0.063180 -0.059767 -0.055610
# J304            -0.069371  1.000000 -0.064219 -0.058628 -0.055462 -0.051604
# K210            -0.069205 -0.064219  1.000000 -0.058488 -0.055329 -0.051481
# L239            -0.063180 -0.058628 -0.058488  1.000000 -0.050512 -0.046999
# K219            -0.059767 -0.055462 -0.055329 -0.050512  1.000000 -0.044460
# J029            -0.055610 -0.051604 -0.051481 -0.046999 -0.044460  1.000000
# J0390           -0.055476 -0.051479 -0.051356 -0.046885 -0.044353 -0.041268
# N400            -0.050106 -0.046496 -0.046385 -0.042347 -0.040060 -0.037273
#
#                     J0390      N400
# STND_Y                NaN       NaN
# IDV_ID           0.000361  0.005526
# KEY_SEQ         -0.016890  0.019037
# SEX              0.014358 -0.198351
# AGE_GROUP       -0.147128  0.117901
# SIDO            -0.003496  0.016152
# FORM_CD               NaN       NaN
# DSBJT_CD         0.084242  0.259917
# VSCN                  NaN       NaN
# RECN                  NaN       NaN
# EDEC_ADD_RT           NaN       NaN
# EDEC_TRAMT       0.045592 -0.085049
# EDEC_SBRDN_AMT   0.117206 -0.085886
# EDEC_JBRDN_AMT  -0.016757 -0.050534
# TOT_PRES_DD_CNT -0.161551  0.102260
# month           -0.016052  0.017174
# cold             0.691524 -0.053770
# I109            -0.156010 -0.140909
# J209            -0.110939 -0.100201
# E119            -0.055476 -0.050106
# J304            -0.051479 -0.046496
# K210            -0.051356 -0.046385
# L239            -0.046885 -0.042347
# K219            -0.044353 -0.040060
# J029            -0.041268 -0.037273
# J0390            1.000000 -0.037183
# N400            -0.037183  1.000000
#
# [27 rows x 27 columns]

# %%
# 주요 질병 10 개의 연령별 분포

ax=sns.countplot(x = 'MAIN_SICK',hue = 'AGE_GROUP', data=dai)
plt.legend(loc='best')

plt.show()

# %%
# 주요 질병 10개의 성별 분포

ax=sns.countplot(x = 'MAIN_SICK',hue = 'SEX', data=dai)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 3, height, ha = 'center', size = 9)
plt.show()
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values

# %%
#계절별 안과질환 분포
sns.countplot(x = 'season', hue = 'desease', data=train)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### 모델링

# %%
#진료수 상위 30개만 가지고 모델링
from sklearn.model_selection import train_test_split

X_data = df.loc[:,['SEX','AGE_GROUP','season','DSBJT_CD']]
y_data = df.loc[:,'MAIN_SICK']

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, shuffle = True, random_state=20)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (448016, 4) (448016,)
# (112005, 4) (112005,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_knn_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
knn_acc = accuracy_score(y_test, y_knn_pred)
print("Accuracy : %4f" %knn_acc)
# Out:
# Accuracy : 0.381554

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')
#svc.fit(X_train,y_train)

# %%
#y_svc_pred = svc.predict(X_test)
#svc_acc = accuracy(y_test, y_svc_pred)
#print("Accuracy : %4f" %svc_acc)

# %%
from sklearn.linear_model import LogisticRegression
lrc = LogisticRegression()
lrc.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
#성능 평가
y_lrc_pred = lrc.predict(X_test)
lrc_acc = accuracy_score(y_test, y_lrc_pred)
print("Accuracy : %4f" %lrc_acc)
# Out:
# Accuracy : 0.354788

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth=3, random_state=20)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=20)

# %%
y_dtc_pred = dtc.predict(X_test)

dtc_acc = accuracy_score(y_test,y_dtc_pred)
print("Accuracy : %4f" %dtc_acc)
# Out:
# Accuracy : 0.363912

# %% [markdown]
# ### 랜덤 포레스트

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100, max_depth=3, random_state = 20)
rfc.fit(X_train, y_train)
#예측
y_rfc_pred = rfc.predict(X_test)

#모델 성능 평가
rfc_acc = accuracy_score(y_test, y_rfc_pred)
print("Accuracy : %4f" %rfc_acc)
# Out:
# Accuracy : 0.369135

# %% [markdown]
# ### 부스팅

# %%
from xgboost import XGBClassifier
xgbc = XGBClassifier(n_estimators=100, max_depth=3, random_state=20)
xgbc.fit(X_train,y_train)
#예측
y_xgbc_pred = xgbc.predict(X_test)

xgbc_acc = accuracy_score(y_test, y_xgbc_pred)
print("Accuracy : %4f" %xgbc_acc)
# Out:
# Accuracy : 0.448516

# %% [markdown]
# ### Kfold

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

kfold = KFold(n_splits=5, shuffle=True, random_state=20)
val_scores = []
num_fold = 1
for tr_idx, val_idx in kfold.split(X_train, y_train):
  X_tr, X_val = X_train.iloc[tr_idx, : ],X_train.iloc[val_idx, :]
  y_tr, y_val = y_train.iloc[tr_idx], y_train.iloc[val_idx]
  #학습
  rfc = RandomForestClassifier(max_depth=5, random_state=20)
  rfc.fit(X_tr, y_tr)
  #검증
  y_val_pred = rfc.predict(X_val)
  val_acc = accuracy_score(y_val, y_val_pred)
  print("%d Fold Accuracy: %.4f"%(num_fold, val_acc))
  val_scores.append(val_acc)
  num_fold +=1
# Out:
# 1 Fold Accuracy: 0.4319
# 2 Fold Accuracy: 0.4333
# 3 Fold Accuracy: 0.4330
# 4 Fold Accuracy: 0.4344
# 5 Fold Accuracy: 0.4347
